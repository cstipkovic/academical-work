# %% [markdown]
# ## Henrique Olivares | 4151418-1

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.images.shape
# Out:
# (1797, 8, 8)

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(10, 10, figsize = (8, 8), subplot_kw = {'xticks':[], 'yticks':[]}, gridspec_kw = dict(hspace = 0.1, wspace = 0.1))
for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap = 'binary', interpolation = 'nearest')
    ax.text(0.05, 0.05, str(digits.target[i]), transform = ax.transAxes, color = 'green')

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 10, random_state = 2)
clusters = kmeans.fit_predict(digits.data)
kmeans.cluster_centers_.shape
# Out:
# (10, 64)

# %%
fig, ax = plt.subplots(2, 5, figsize = (8, 3))
centers = kmeans.cluster_centers_.reshape(10, 8, 8)
for axi, center in zip(ax.flat, centers):
    axi.set(xticks = [], yticks = [])
    axi.imshow(center, interpolation = 'nearest', cmap = plt.cm.binary)

# %%
import numpy as np
from scipy.stats import mode
from sklearn.metrics import accuracy_score

labels = np.zeros_like(clusters)
for i in range(10):
    mask = (clusters == i)
    labels[mask] = mode(digits.target[mask])[0]
accuracy_score(digits.target, labels)
# Out:
# 0.7952142459654981

# %% [markdown]
# a) quais dígitos foram corretamente agrupados (se algum)
#
# Os dígitos que foram corretamente agrupados são 0, 2, 3, 4, 5, 6, 7, 9

# %% [markdown]
# b) quais dígitos foram erroneamente agrupados (se algum)
#
# Os dígitos que foram erroneamente agrupados são 1 e 8
